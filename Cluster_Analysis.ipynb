# %% [markdown]
# <a href="https://colab.research.google.com/github/datagrad/1.ML/blob/main/Cluster_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cluster Analysis
#
# [statinfer.com](https://statinfer.com/)

# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# # Clustering on Super market Data

# %%
#Cluster Analysis
sup_market = pd.read_csv("https://raw.githubusercontent.com/venkatareddykonasani/Datasets/master/Super%20Market%20Coupons/Super_market_Coupons.csv")


sup_market.head()
# Out:
#    cust_id  age  Estimated_income  recent_spends  family_size  \
# 0        1   30              3300     771.572261            1
# 1        2   46             12454     128.922027            3
# 2        3   76                 0       0.000000            1
# 3        4   38              3000      76.967031            3
# 4        5   39              2500    2499.999750            1
#
#    Avg_visits_permonth
# 0                    4
# 1                    3
# 2                    8
# 3                    3
# 4                    1

# %%
sup_market = sup_market.drop(['cust_id'],axis =1)
sup_market
# Out:
#       age  Estimated_income  recent_spends  family_size  Avg_visits_permonth
# 0      30              3300     771.572261            1                    4
# 1      46             12454     128.922027            3                    3
# 2      76                 0       0.000000            1                    8
# 3      38              3000      76.967031            3                    3
# 4      39              2500    2499.999750            1                    1
# ...   ...               ...            ...          ...                  ...
# 2995   35              7174    6315.360412            1                    2
# 2996   76                 0       0.000000            1                    1
# 2997   50                 0       0.000000            1                    9
# 2998   35              5100    1549.296360            2                    5
# 2999   49               400      63.997218            1                   10
#
# [3000 rows x 5 columns]

# %%
sup_market.head()
# Out:
#    age  Estimated_income  recent_spends  family_size  Avg_visits_permonth
# 0   30              3300     771.572261            1                    4
# 1   46             12454     128.922027            3                    3
# 2   76                 0       0.000000            1                    8
# 3   38              3000      76.967031            3                    3
# 4   39              2500    2499.999750            1                    1

# %% [markdown]
# ## Model building

# %%
#Building Clusters here
from sklearn.cluster import KMeans
kmeans_model = KMeans(n_clusters=5,
                      random_state=333) # Mention the Number of clusters

X=sup_market # Custid is not needed
kmeans_result = kmeans_model.fit(X) #Model building
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Getting the cluster labels and attaching them to the original data
labels = kmeans_result.predict(X)
sup_market["Cluster_id"]=labels
sup_market.head()
# Out:
#    age  Estimated_income  recent_spends  family_size  Avg_visits_permonth  \
# 0   30              3300     771.572261            1                    4
# 1   46             12454     128.922027            3                    3
# 2   76                 0       0.000000            1                    8
# 3   38              3000      76.967031            3                    3
# 4   39              2500    2499.999750            1                    1
#
#    Cluster_id
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0

# %%
sup_market["Cluster_id"].value_counts()
# Out:
# 0    2118
# 1     875
# 2       7
# Name: Cluster_id, dtype: int64

# %%
sup_market.groupby("Cluster_id").median()

# sup_market.groupby("Cluster_id").mean()
# Out:
#              age  Estimated_income  recent_spends  family_size  \
# Cluster_id
# 0           52.0            2800.0     145.238006          1.0
# 1           52.0            9610.0    1997.045568          2.0
# 2           55.0           55000.0   22384.357340          2.0
#
#             Avg_visits_permonth
# Cluster_id
# 0                           6.0
# 1                           5.0
# 2                           9.0

# %% [markdown]
# # Output Inference

# %%
#The Final Target population
target_data=sup_market[(sup_market["Cluster_id"]==1) | (sup_market["Cluster_id"]==3)]
print(target_data.shape)
# Out:
# (875, 6)
